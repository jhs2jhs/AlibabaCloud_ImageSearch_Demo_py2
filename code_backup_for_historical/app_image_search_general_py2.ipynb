# %% [markdown]
# # this demo show how to do a general search for similar images

# %% [markdown]
# # this demo is setup using python2

# %%
# setup envionrmnet
#! python2 -m pip install aliyun-python-sdk-imagesearch
#! python2 -m pip install pillow

# %%
#from IPython.display 
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from IPython.display import display
from IPython.core.display import HTML 
import json
from pprint import pprint
import os
import time
#import md5
import hashlib
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: the md5 module is deprecated; use hashlib instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
def get_md5(txt):
    #return md5.new(txt).digest()
    return hashlib.sha224(txt).hexdigest()

# %%
def image_preview(image_path, box, cate):
    #img1 = Image(filename = image_path, width=100, height=100)
    img1 = Image.open(image_path)
    if box is not None and box != '':
        draw = ImageDraw.Draw(img1)
        bb = box.split(",")
        x0 = float(bb[0])
        y0 = float(bb[2])
        x1 = float(bb[1])
        x2 = float(bb[3])
        draw.rectangle([(x0, y0), (x1, x2)], outline='red')
        if cate is not None and cate != "":
            draw.text((x0, y0), cate, fill="red")
    img = img1
    return img

# %%
PATH = "/Users/jianhuashao/code/demo_imagesearch/images_bottle/"
image_path = PATH + "1.jpg"
img = image_preview(image_path, "74,139,19,217", 'bottle')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107B93310>

# %% [markdown]
# # credential is setup in a seperate ali_config.py

# %%
from aliyunsdkcore import client
from aliyunsdkcore.profile import region_provider

import ali_config

product = "ImageSearch"
region = ali_config.region # via: cn-shanghai(sh), ap-southeast-1(sg)
accessKeyId = ali_config.accessKeyId # via: https://ak-console.aliyun.com
accessKeySecret = ali_config.accessKeySecret
domain = "imagesearch."+ region +".aliyuncs.com"

instanceName = "isdemogeneral"

region_provider.add_endpoint(product, region, domain)
requestClient = client.AcsClient(accessKeyId, accessKeySecret, region)

# %% [markdown]
# # function to upload image into alibaba cloud

# %%
from aliyunsdkimagesearch.request.v20180120.AddItemRequest import AddItemRequest

def image_upload(instanceName, image_name, image_path):
    # load file
    file_object = open(image_path)
    file_content = None
    try:
        file_content = file_object.read()
    finally:
        file_object.close()
        
    img_id = get_md5(file_content)
    print('img_id: ', img_id)

    request = AddItemRequest()
    request.set_instance_name(instanceName)
    request.set_cate_id("0")
    request.set_item_id(img_id)
    image_content = {'name': image_name, 'path': image_path, 'img_id': img_id}
    request.set_cust_content(json.dumps(image_content))

    print len(file_content)
    request.add_picture(image_name, file_content)
    request.build_post_content()

    result = requestClient.do_action(request)
    return result

# %%
# test to upload a single image

#instanceName = "testforbcgeneral"; # e.g. imagesearchtest
image_name = '1.jpg'
image_folder = '../images_bottle'
image_path = os.path.abspath(image_folder+'/'+image_name)
result = image_upload(instanceName, image_name, image_path)
print(image_path, result)
# Out:
# ('img_id: ', '5c47a64b53c64d8155a4389ec36ed7b0126754cf36d8fe33f0f94abc')
# 2965
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg', '{"Message":"success","RequestId":"2CBF3871-91F4-4DE2-988D-51DF64BEB53C","Success":true,"Code":0}')

# %%
# test to upload a list of image

import os
import time
from pprint import pprint

image_folder = os.path.abspath('../images_bottle')
images = {}
for file in os.listdir(image_folder):
    if file.endswith(".jpg"):
        image_path = os.path.join(image_folder, file)
        #print(os.path.abspath(image_path))
        images[image_path] = file

pprint(images)

for image_path in images:
    image_name = images[image_path]
    result = image_upload(instanceName, image_name, image_path)
    print(instanceName, image_name, image_path, result)
    time.sleep(1)
# Out:
# {'/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg': '003-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/008-220x220.jpg': '008-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg': '1.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/2.jpg': '2.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/3.jpg': '3.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/4.jpg': '4.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg': '5.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/6.jpg': '6.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/7.jpg': '7.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/8.jpg': '8.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg': '9.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg': 'IMG_20160507_111836-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg': 'IMG_20160507_112417-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/WaterBottle11-220x220.jpg': 'WaterBottle11-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/bottle-sm-decanter.jpg': 'bottle-sm-decanter.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/downloadcoca-220x220.jpg': 'downloadcoca-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/prodcat_glass-vials-roller-ball-bottles-220x220.jpg': 'prodcat_glass-vials-roller-ball-bottles-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/tgtgsu1724102.220x220.95b56.jpg': 'tgtgsu1724102.220x220.95b56.jpg'}
# ('img_id: ', '18e44724ef73f46298bb190539898904029d97deb2c6234fa24e4260')
# 7349
# ('isdemogeneral', '7.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/7.jpg', '{"Message":"success","RequestId":"E4AC260F-CF32-4411-BD03-35A26CE8DA89","Success":true,"Code":0}')
# ('img_id: ', 'da1908d43ed162a76c1598d22a1465a9fb43f50a1aea8d2cca49ccc7')
# 5923
# ('isdemogeneral', '5.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg', '{"Message":"success","RequestId":"78606168-271B-43E6-8123-1347F3EC570C","Success":true,"Code":0}')
# ('img_id: ', '8872e6abf4746903685f0861f41b22d8e57523abbd467da277cea65a')
# 3226
# ('isdemogeneral', '3.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/3.jpg', '{"Message":"success","RequestId":"F7378C77-2911-44E8-AC82-D1205356E6F9","Success":true,"Code":0}')
# ('img_id: ', 'bdfa1c7a4f4bb1e84497e038518643db563c98916cfa02e420407d8f')
# 7898
# ('isdemogeneral', '4.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/4.jpg', '{"Message":"success","RequestId":"70A3B3EC-FF3F-48A4-9EF8-BD6858960B90","Success":true,"Code":0}')
# ('img_id: ', '5c47a64b53c64d8155a4389ec36ed7b0126754cf36d8fe33f0f94abc')
# 2965
# ('isdemogeneral', '1.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg', '{"Message":"success","RequestId":"4EDC7CA1-D960-4F94-8459-501833C4848F","Success":true,"Code":0}')
# ('img_id: ', '9a0199e9fee78a7f1efe5b4bcf8d4b19097300e6b5b6949efbb705a8')
# 11936
# ('isdemogeneral', 'WaterBottle11-220x220.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/WaterBottle11-220x220.jpg', '{"Message":"success","RequestId":"0AE718C3-57DF-4F15-808C-FCC0176AF741","Success":true,"Code":0}')
# ('img_id: ', 'f9f26adb1f6bfc02e9376249850b9f924eaadcb0ae1ade83503cd5e9')
# 6802
# ('isdemogeneral', '6.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/6.jpg', '{"Message":"success","RequestId":"C84A1399-6C40-4C9D-B44D-356FDCA8C9B8","Success":true,"Code":0}')
# ('img_id: ', 'f728643c806d3f47d0d882ec294e1981b2240d9df3f418957cc5cafc')
# 35389
# ('isdemogeneral', 'bottle-sm-decanter.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/bottle-sm-decanter.jpg', '{"Message":"success","RequestId":"B2809666-908E-41F9-838E-6D8D240A62FE","Success":true,"Code":0}')
# ('img_id: ', 'f8509dec903cf12693b9a5f6086c99f50d4926ed7831651524461069')
# 12024
# ('isdemogeneral', '003-220x220.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg', '{"Message":"success","RequestId":"EF47549F-47B4-4FBB-BB89-ED4EDB560F58","Success":true,"Code":0}')
# ('img_id: ', '7608e199a1ea31120b54b8547337533115347ffa690a3ed9dfa68c95')
# 8574
# ('isdemogeneral', '9.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg', '{"Message":"success","RequestId":"0125BB7A-58BD-4FB8-B1FF-17C843BEFB7A","Success":true,"Code":0}')
# ('img_id: ', 'ed4e1babe9d722643b435c1a3c99a9f9fd6e30002acc082944738b88')
# 4464
# ('isdemogeneral', 'prodcat_glass-vials-roller-ball-bottles-220x220.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/prodcat_glass-vials-roller-ball-bottles-220x220.jpg', '{"Message":"success","RequestId":"07BA6FA9-B3EF-413F-BE36-013E1E65C0D3","Success":true,"Code":0}')
# ('img_id: ', '9e14560e344a30c474f1bd665c9ed8886ea00ee0bc4d969f35fea407')
# 4660
# ('isdemogeneral', '2.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/2.jpg', '{"Message":"success","RequestId":"4EB2B4FD-92EC-4028-BED8-3797D2813E91","Success":true,"Code":0}')
# ('img_id: ', '098c65360d71a0d92fdb6d4eeb0ab4841c9556355e72493e073b915a')
# 4675
# ('isdemogeneral', '008-220x220.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/008-220x220.jpg', '{"Message":"success","RequestId":"799BBA9D-8CE7-4E17-9B25-B9D1FDAF04BA","Success":true,"Code":0}')
# ('img_id: ', '340900c63f7aeced1513bbf9f6163b7c38641207a0aa71407cdc8004')
# 9927
# ('isdemogeneral', 'IMG_20160507_111836-220x220.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg', '{"Message":"success","RequestId":"5C458C2B-325A-455C-9058-956DF82D35CC","Success":true,"Code":0}')
# ('img_id: ', 'b5f89255992781ee3535c78aac467d413d79e009664143cf7f130ea8')
# 6525
# ('isdemogeneral', 'downloadcoca-220x220.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/downloadcoca-220x220.jpg', '{"Message":"success","RequestId":"6E895422-0B7C-4CB1-890D-B2F21D783A15","Success":true,"Code":0}')
# ('img_id: ', '80c2ffc0427e0aa7bee12edbfc1d3622bf4f053fc067eaa1835e41d0')
# 12249
# ('isdemogeneral', 'IMG_20160507_112417-220x220.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg', '{"Message":"success","RequestId":"870739C6-8FA7-4D3F-9A2B-B11D87104941","Success":true,"Code":0}')
# ('img_id: ', '21653c0b4316583c9785173ac5869edd69bb41ace7b729630305c78f')
# 5203
# ('isdemogeneral', '8.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/8.jpg', '{"Message":"success","RequestId":"4ABE12AD-B002-4384-94DD-395CDB91405B","Success":true,"Code":0}')
# ('img_id: ', 'ffe2778b039943c1856bcb747d982b9480e834f97473e24398afc243')
# 14344
# ('isdemogeneral', 'tgtgsu1724102.220x220.95b56.jpg', '/Users/jianhuashao/code/demo_imagesearch/images_bottle/tgtgsu1724102.220x220.95b56.jpg', '{"Message":"success","RequestId":"8140D686-4CAE-4857-A225-50A58C72981F","Success":true,"Code":0}')

# %% [markdown]
# # function to search for image in alibaba cloud

# %%
from aliyunsdkimagesearch.request.v20180120.SearchItemRequest import SearchItemRequest

def image_search(instanceName, image_path):
    request = SearchItemRequest()

    request.set_instance_name(instanceName)
    request.set_num(20)
    request.set_start(0)

    file_object = open(image_path)
    file_content = None
    try:
        file_content = file_object.read()
    finally:
        file_object.close()

    request.set_search_picture(file_content)

    request.build_post_content()

    result = requestClient.do_action(request)
    return result

# %%
def image_search_result(instanceName, image_path):
    result = image_search(instanceName, image_path)
    r = json.loads(result)
    #pprint(r)
    category_desc = ''
    for c in r['PicInfo']['AllCategory']['Category']:
        if r['PicInfo']['Category'] == c['Id']:
            category_desc = c['Name']
    #pprint(r)
    display(image_preview(image_path, r['PicInfo']['Region'], category_desc))
    
    print(image_path, 'found category_desc: ', category_desc, r['PicInfo']['Category'], 'found category_id: ', r['PicInfo']['Category'], 'found region: ',  r['PicInfo']['Region'])
    
    image_similar_name = json.loads(r['Auctions']['Auction'][1]['CustContent'])['name']
    image_similar_path = json.loads(r['Auctions']['Auction'][1]['CustContent'])['path']
    image_similar_score = r['Auctions']['Auction'][0]['SortExprValues']
    print("similar score: ", image_similar_score, "similar image: ", image_similar_path)
    
    #print(r['Auctions']['Auction'][1])
    display(image_preview(image_similar_path, '', ''))
    
    return r

# %%
# test to search a single image

#instanceName = "testforbcgeneral"; # e.g. imagesearchtest
image_name = '1.jpg'
image_folder = '../images_bottle'
image_path = os.path.abspath(image_folder+'/'+image_name)
r = image_search_result(instanceName, image_path)
pprint(r)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CA1E50>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'74,139,19,217')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107B86B50>
# {u'Auctions': {u'Auction': [{u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg", "name": "1.jpg", "img_id": "5c47a64b53c64d8155a4389ec36ed7b0126754cf36d8fe33f0f94abc"}',
#                              u'ItemId': u'5c47a64b53c64d8155a4389ec36ed7b0126754cf36d8fe33f0f94abc',
#                              u'PicName': u'1.jpg',
#                              u'SortExprValues': u'5.37633353624177e+24;0'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg", "name": "003-220x220.jpg", "img_id": "f8509dec903cf12693b9a5f6086c99f50d4926ed7831651524461069"}',
#                              u'ItemId': u'f8509dec903cf12693b9a5f6086c99f50d4926ed7831651524461069',
#                              u'PicName': u'003-220x220.jpg',
#                              u'SortExprValues': u'3.37857913970947;246'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/3.jpg", "name": "3.jpg", "img_id": "8872e6abf4746903685f0861f41b22d8e57523abbd467da277cea65a"}',
#                              u'ItemId': u'8872e6abf4746903685f0861f41b22d8e57523abbd467da277cea65a',
#                              u'PicName': u'3.jpg',
#                              u'SortExprValues': u'3.22502589225769;220'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/prodcat_glass-vials-roller-ball-bottles-220x220.jpg", "name": "prodcat_glass-vials-roller-ball-bottles-220x220.jpg", "img_id": "ed4e1babe9d722643b435c1a3c99a9f9fd6e30002acc082944738b88"}',
#                              u'ItemId': u'ed4e1babe9d722643b435c1a3c99a9f9fd6e30002acc082944738b88',
#                              u'PicName': u'prodcat_glass-vials-roller-ball-bottles-220x220.jpg',
#                              u'SortExprValues': u'3.12033295631409;258'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/2.jpg", "name": "2.jpg", "img_id": "9e14560e344a30c474f1bd665c9ed8886ea00ee0bc4d969f35fea407"}',
#                              u'ItemId': u'9e14560e344a30c474f1bd665c9ed8886ea00ee0bc4d969f35fea407',
#                              u'PicName': u'2.jpg',
#                              u'SortExprValues': u'3.01736068725586;240'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg", "name": "9.jpg", "img_id": "7608e199a1ea31120b54b8547337533115347ffa690a3ed9dfa68c95"}',
#                              u'ItemId': u'7608e199a1ea31120b54b8547337533115347ffa690a3ed9dfa68c95',
#                              u'PicName': u'9.jpg',
#                              u'SortExprValues': u'3.00858068466187;256'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/008-220x220.jpg", "name": "008-220x220.jpg", "img_id": "098c65360d71a0d92fdb6d4eeb0ab4841c9556355e72493e073b915a"}',
#                              u'ItemId': u'098c65360d71a0d92fdb6d4eeb0ab4841c9556355e72493e073b915a',
#                              u'PicName': u'008-220x220.jpg',
#                              u'SortExprValues': u'2.97418403625488;246'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/4.jpg", "name": "4.jpg", "img_id": "bdfa1c7a4f4bb1e84497e038518643db563c98916cfa02e420407d8f"}',
#                              u'ItemId': u'bdfa1c7a4f4bb1e84497e038518643db563c98916cfa02e420407d8f',
#                              u'PicName': u'4.jpg',
#                              u'SortExprValues': u'2.97002172470093;247'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/6.jpg", "name": "6.jpg", "img_id": "f9f26adb1f6bfc02e9376249850b9f924eaadcb0ae1ade83503cd5e9"}',
#                              u'ItemId': u'f9f26adb1f6bfc02e9376249850b9f924eaadcb0ae1ade83503cd5e9',
#                              u'PicName': u'6.jpg',
#                              u'SortExprValues': u'2.84773468971252;228'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/bottle-sm-decanter.jpg", "name": "bottle-sm-decanter.jpg", "img_id": "f728643c806d3f47d0d882ec294e1981b2240d9df3f418957cc5cafc"}',
#                              u'ItemId': u'f728643c806d3f47d0d882ec294e1981b2240d9df3f418957cc5cafc',
#                              u'PicName': u'bottle-sm-decanter.jpg',
#                              u'SortExprValues': u'2.77292585372925;243'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg", "name": "IMG_20160507_112417-220x220.jpg", "img_id": "80c2ffc0427e0aa7bee12edbfc1d3622bf4f053fc067eaa1835e41d0"}',
#                              u'ItemId': u'80c2ffc0427e0aa7bee12edbfc1d3622bf4f053fc067eaa1835e41d0',
#                              u'PicName': u'IMG_20160507_112417-220x220.jpg',
#                              u'SortExprValues': u'2.75069904327393;245'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg", "name": "5.jpg", "img_id": "da1908d43ed162a76c1598d22a1465a9fb43f50a1aea8d2cca49ccc7"}',
#                              u'ItemId': u'da1908d43ed162a76c1598d22a1465a9fb43f50a1aea8d2cca49ccc7',
#                              u'PicName': u'5.jpg',
#                              u'SortExprValues': u'2.71495413780212;274'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/8.jpg", "name": "8.jpg", "img_id": "21653c0b4316583c9785173ac5869edd69bb41ace7b729630305c78f"}',
#                              u'ItemId': u'21653c0b4316583c9785173ac5869edd69bb41ace7b729630305c78f',
#                              u'PicName': u'8.jpg',
#                              u'SortExprValues': u'2.67160272598267;263'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/downloadcoca-220x220.jpg", "name": "downloadcoca-220x220.jpg", "img_id": "b5f89255992781ee3535c78aac467d413d79e009664143cf7f130ea8"}',
#                              u'ItemId': u'b5f89255992781ee3535c78aac467d413d79e009664143cf7f130ea8',
#                              u'PicName': u'downloadcoca-220x220.jpg',
#                              u'SortExprValues': u'2.6525342464447;244'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/7.jpg", "name": "7.jpg", "img_id": "18e44724ef73f46298bb190539898904029d97deb2c6234fa24e4260"}',
#                              u'ItemId': u'18e44724ef73f46298bb190539898904029d97deb2c6234fa24e4260',
#                              u'PicName': u'7.jpg',
#                              u'SortExprValues': u'2.6190242767334;267'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/tgtgsu1724102.220x220.95b56.jpg", "name": "tgtgsu1724102.220x220.95b56.jpg", "img_id": "ffe2778b039943c1856bcb747d982b9480e834f97473e24398afc243"}',
#                              u'ItemId': u'ffe2778b039943c1856bcb747d982b9480e834f97473e24398afc243',
#                              u'PicName': u'tgtgsu1724102.220x220.95b56.jpg',
#                              u'SortExprValues': u'2.61847162246704;271'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg", "name": "IMG_20160507_111836-220x220.jpg", "img_id": "340900c63f7aeced1513bbf9f6163b7c38641207a0aa71407cdc8004"}',
#                              u'ItemId': u'340900c63f7aeced1513bbf9f6163b7c38641207a0aa71407cdc8004',
#                              u'PicName': u'IMG_20160507_111836-220x220.jpg',
#                              u'SortExprValues': u'2.53796172142029;242'},
#                             {u'CatId': u'88888888',
#                              u'CustContent': u'{"path": "/Users/jianhuashao/code/demo_imagesearch/images_bottle/WaterBottle11-220x220.jpg", "name": "WaterBottle11-220x220.jpg", "img_id": "9a0199e9fee78a7f1efe5b4bcf8d4b19097300e6b5b6949efbb705a8"}',
#                              u'ItemId': u'9a0199e9fee78a7f1efe5b4bcf8d4b19097300e6b5b6949efbb705a8',
#                              u'PicName': u'WaterBottle11-220x220.jpg',
#                              u'SortExprValues': u'2.48474860191345;282'}]},
#  u'Code': 0,
#  u'Head': {u'DocsFound': 18, u'DocsReturn': 18, u'SearchTime': 51},
#  u'Message': u'success',
#  u'PicInfo': {u'AllCategory': {u'Category': [{u'Id': u'0',
#                                               u'Name': u'Tops'},
#                                              {u'Id': u'1',
#                                               u'Name': u'Dress'},
#                                              {u'Id': u'2',
#                                               u'Name': u'Bottoms'},
#                                              {u'Id': u'3', u'Name': u'Bag'},
#                                              {u'Id': u'4',
#                                               u'Name': u'Shoes'},
#                                              {u'Id': u'5',
#                                               u'Name': u'Accessories'},
#                                              {u'Id': u'6',
#                                               u'Name': u'Snack'},
#                                              {u'Id': u'7',
#                                               u'Name': u'Makeup'},
#                                              {u'Id': u'8',
#                                               u'Name': u'Bottle'},
#                                              {u'Id': u'9',
#                                               u'Name': u'Furniture'},
#                                              {u'Id': u'20',
#                                               u'Name': u'Toy'},
#                                              {u'Id': u'21',
#                                               u'Name': u'Underwear'},
#                                              {u'Id': u'22',
#                                               u'Name': u'Digital device'},
#                                              {u'Id': u'88888888',
#                                               u'Name': u'Other'}]},
#               u'Category': u'88888888',
#               u'Region': u'74,139,19,217'},
#  u'RequestId': u'62CB431B-64D6-40D2-B491-9E0BC52709EA',
#  u'Success': True}

# %%
image_folder = os.path.abspath('../images_bottle')
images = {}
for file in os.listdir(image_folder):
    if file.endswith(".jpg"):
        image_path = os.path.join(image_folder, file)
        #print(os.path.abspath(image_path))
        images[image_path] = file

pprint(images)

for image_path in images:
    image_name = images[image_path]
    r = image_search_result(instanceName, image_path)
    print("\n=======\n")
# Out:
# {'/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg': '003-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/008-220x220.jpg': '008-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg': '1.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/2.jpg': '2.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/3.jpg': '3.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/4.jpg': '4.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg': '5.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/6.jpg': '6.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/7.jpg': '7.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/8.jpg': '8.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg': '9.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg': 'IMG_20160507_111836-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg': 'IMG_20160507_112417-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/WaterBottle11-220x220.jpg': 'WaterBottle11-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/bottle-sm-decanter.jpg': 'bottle-sm-decanter.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/downloadcoca-220x220.jpg': 'downloadcoca-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/prodcat_glass-vials-roller-ball-bottles-220x220.jpg': 'prodcat_glass-vials-roller-ball-bottles-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/tgtgsu1724102.220x220.95b56.jpg': 'tgtgsu1724102.220x220.95b56.jpg'}
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE07D0>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/7.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'50,168,3,212')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/6.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0710>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'77,136,43,212')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/prodcat_glass-vials-roller-ball-bottles-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0710>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE07D0>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/3.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'74,135,23,189')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0850>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x107CE0810>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/4.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'103,196,8,294')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE07D0>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0790>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'74,139,19,217')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0810>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/WaterBottle11-220x220.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'51,140,59,219')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0710>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/6.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'51,164,2,216')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/7.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0850>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x107CE0710>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/bottle-sm-decanter.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'242,556,34,787')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0710>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'81,148,10,200')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0810>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'108,191,1,218')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/3.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE07D0>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0790>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/prodcat_glass-vials-roller-ball-bottles-220x220.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'148,192,72,206')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0790>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0810>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/2.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'64,157,2,217')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/008-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0710>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/008-220x220.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'62,157,8,208')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/2.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0710>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0810>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'10,200,43,200')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0790>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/downloadcoca-220x220.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'69,143,3,216')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/4.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x107CE0750>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0810>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'91,141,23,202')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0710>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0790>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/8.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'72,138,1,216')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE07D0>
# =======
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE0750>
# ('/Users/jianhuashao/code/demo_imagesearch/images_bottle/tgtgsu1724102.220x220.95b56.jpg', 'found category_desc: ', u'Other', u'88888888', 'found category_id: ', u'88888888', 'found region: ', u'66,148,2,219')
# ('similar score: ', u'5.37633353624177e+24;0', 'similar image: ', u'/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg')
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x220 at 0x107CE07D0>
# =======

# %% [markdown]
# # delete images

# %%
from aliyunsdkimagesearch.request.v20180120.DeleteItemRequest import DeleteItemRequest

def image_delete(instanceName, image_path, image_name):
    file_object = open(image_path)
    file_content = None
    try:
        file_content = file_object.read()
    finally:
        file_object.close()
        
    img_id = get_md5(file_content)
    print('img_id: ', img_id)
    
    request = DeleteItemRequest()
    
    request.set_item_id(img_id)
    request.add_picture(image_name)

    request.build_post_content()

    result = requestClient.do_action(request)
    return result

# %%
image_folder = os.path.abspath('../images_bottle')
images = {}
for file in os.listdir(image_folder):
    if file.endswith(".jpg"):
        image_path = os.path.join(image_folder, file)
        #print(os.path.abspath(image_path))
        images[image_path] = file

pprint(images)

for image_path in images:
    image_name = images[image_path]
    r = image_delete(instanceName, image_path, image_name)
    print("\n=======\n")
# Out:
# {'/Users/jianhuashao/code/demo_imagesearch/images_bottle/003-220x220.jpg': '003-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/008-220x220.jpg': '008-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/1.jpg': '1.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/2.jpg': '2.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/3.jpg': '3.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/4.jpg': '4.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/5.jpg': '5.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/6.jpg': '6.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/7.jpg': '7.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/8.jpg': '8.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/9.jpg': '9.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_111836-220x220.jpg': 'IMG_20160507_111836-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/IMG_20160507_112417-220x220.jpg': 'IMG_20160507_112417-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/WaterBottle11-220x220.jpg': 'WaterBottle11-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/bottle-sm-decanter.jpg': 'bottle-sm-decanter.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/downloadcoca-220x220.jpg': 'downloadcoca-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/prodcat_glass-vials-roller-ball-bottles-220x220.jpg': 'prodcat_glass-vials-roller-ball-bottles-220x220.jpg',
#  '/Users/jianhuashao/code/demo_imagesearch/images_bottle/tgtgsu1724102.220x220.95b56.jpg': 'tgtgsu1724102.220x220.95b56.jpg'}
# ('img_id: ', '18e44724ef73f46298bb190539898904029d97deb2c6234fa24e4260')
#
# =======
#
# ('img_id: ', 'da1908d43ed162a76c1598d22a1465a9fb43f50a1aea8d2cca49ccc7')
#
# =======
#
# ('img_id: ', '8872e6abf4746903685f0861f41b22d8e57523abbd467da277cea65a')
#
# =======
#
# ('img_id: ', 'bdfa1c7a4f4bb1e84497e038518643db563c98916cfa02e420407d8f')
#
# =======
#
# ('img_id: ', '5c47a64b53c64d8155a4389ec36ed7b0126754cf36d8fe33f0f94abc')
#
# =======
#
# ('img_id: ', '9a0199e9fee78a7f1efe5b4bcf8d4b19097300e6b5b6949efbb705a8')
#
# =======
#
# ('img_id: ', 'f9f26adb1f6bfc02e9376249850b9f924eaadcb0ae1ade83503cd5e9')
#
# =======
#
# ('img_id: ', 'f728643c806d3f47d0d882ec294e1981b2240d9df3f418957cc5cafc')
#
# =======
#
# ('img_id: ', 'f8509dec903cf12693b9a5f6086c99f50d4926ed7831651524461069')
#
# =======
#
# ('img_id: ', '7608e199a1ea31120b54b8547337533115347ffa690a3ed9dfa68c95')
#
# =======
#
# ('img_id: ', 'ed4e1babe9d722643b435c1a3c99a9f9fd6e30002acc082944738b88')
#
# =======
#
# ('img_id: ', '9e14560e344a30c474f1bd665c9ed8886ea00ee0bc4d969f35fea407')
#
# =======
#
# ('img_id: ', '098c65360d71a0d92fdb6d4eeb0ab4841c9556355e72493e073b915a')
#
# =======
#
# ('img_id: ', '340900c63f7aeced1513bbf9f6163b7c38641207a0aa71407cdc8004')
#
# =======
#
# ('img_id: ', 'b5f89255992781ee3535c78aac467d413d79e009664143cf7f130ea8')
#
# =======
#
# ('img_id: ', '80c2ffc0427e0aa7bee12edbfc1d3622bf4f053fc067eaa1835e41d0')
#
# =======
#
# ('img_id: ', '21653c0b4316583c9785173ac5869edd69bb41ace7b729630305c78f')
#
# =======
#
# ('img_id: ', 'ffe2778b039943c1856bcb747d982b9480e834f97473e24398afc243')
#
# =======
